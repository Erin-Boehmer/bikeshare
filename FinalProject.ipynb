# %% [markdown]
# # Modeling Capital Bike Share Demand

# %%
# %matplotlib inline

#Libraries
import re
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# SK-learn libraries for learning.
from sklearn.feature_extraction import DictVectorizer
from sklearn.cross_validation import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.grid_search import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn import tree
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor

# SK-learn libraries for evaluation.
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

import csv
import fileinput
import sys
import math
from datetime import date

# %matplotlib inline

# %% [markdown]
# ***
# Problem Statement
# ---
#
# You must predict the total count of bikes rented during each hour covered by the test set, using only information available prior to the rental period.
#
#
# Associated tasks
# ---
#
# 	- Regression:
# 		Predication of bike rental count hourly or daily based on the environmental and seasonal settings.
#
# 	- Event and Anomaly Detection:
# 		Count of rented bikes are also correlated to some events in the town which easily are traceable via search engines.
# 		For instance, query like "2012-10-30 washington d.c." in Google returns related results to Hurricane Sandy. Some of the
#         important events are identified in [1]. Therefore the data can be used for validation of anomaly or event detection
#         algorithms as well.
#
#
# Raw Dataset Characteristics
# ---
# Both hour.csv and day.csv have the following fields, except hr which is not available in day.csv
#
# 	- instant: record index
# 	- dteday : date
# 	- season : season (1:springer, 2:summer, 3:fall, 4:winter)
# 	- yr : year (0: 2011, 1:2012)
# 	- mnth : month ( 1 to 12)
# 	- hr : hour (0 to 23)
# 	- holiday : weather day is holiday or not (extracted from http://dchr.dc.gov/page/holiday-schedule)
# 	- weekday : day of the week
# 	- workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# 	+ weathersit :
# 		- 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 		- 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 		- 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 		- 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# 	- temp : Normalized temperature in Celsius. The values are divided to 41 (max)
# 	- atemp: Normalized feeling temperature in Celsius. The values are divided to 50 (max)
# 	- hum: Normalized humidity. The values are divided to 100 (max)
# 	- windspeed: Normalized wind speed. The values are divided to 67 (max)
# 	- casual: count of casual users
# 	- registered: count of registered users
# 	- cnt: count of total rental bikes including both casual and registered
# ***

# %% [markdown]
# ## Data Import

# %% [markdown]
# The first step is to import the data from Kaggle (train.csv and test.csv). We store the train data as "data" because this will later be split into train and test sets. Test.csv is imported as 'dev' so that we can save it for final testing and submission.
#
# We also import hourly precipitation and extreme weather data for the DC area. This data was gathered from an external source (NOAA) and primarily used to help predict anomalies in the data.

# %%
# Pull data into dataframes from Kaggle site (https://www.kaggle.com/c/bike-sharing-demand/data) using pandas
pd_data=pd.read_csv("Bike-Sharing-Dataset/train.csv") 
pd_dev=pd.read_csv("Bike-Sharing-Dataset/test.csv")
timestamps = pd_dev['datetime'] # save original timestamp values from raw data for Kaggle submissions

# import added external data
pd_extreme=pd.read_csv("added_data/extreme_weather.csv", header=None, names=['datetime', 'ex_weather']) 
pd_precip=pd.read_csv("added_data/precipitation.csv", header=None, names = ['datetime', 'precip'])

# %% [markdown]
# ## Data Cleaning and Feature Engineering

# %% [markdown]
# First, we define several utility functions that are used for feature engineering. We will call these later with our pd_data and pd_dev dataframes as parameters.

# %%
# splits datetime value in form "2011-01-20 05:00:00" to 6 columns ['2011' '01' '01' '00' '00' '00']
# the funciton also converts day of the month to day of week
def dateTransform(data, dateCol='datetime', split=True):
    data.index = pd.to_datetime(data[dateCol]) # creating an index from the timestamp
    data.pop(dateCol) # now that the dateCol is an index, remove that column from the dataframe
    
    if split:
        data['year']=data.index.year # create a column for year
        data['month']=data.index.month # create a column for month
        data['hours']=data.index.hour # create a column for hours 
        data['day']=data.index.dayofweek # translates the date to day of week (Monday=0, Sunday=6)
    return data

#function to create dummy variables on categorical variables
def dummify(data, cols):
    for v in cols:
        dummy=pd.get_dummies(data[v], prefix= v)
        data=data.join(dummy)
        data.pop(v)
    return data

def binHours(data):
    data['hourBin']=pd.cut(data.hours.astype(int), bins=[-1,5,11,17,23], labels=['0_5','6_11','12_17','18_23']) 
    return data

# this binarizes the extreme weather data into 1 for "extreme" and 0 for "normal"
def binarize(df):
    df['ex_weather'] = df['ex_weather'].notnull().astype(int)
    df.astype(int)
    return df

# %% [markdown]
# Now we begin by adding the precipitation and extreme weather data to the dataframe. Some data cleaning is needed before we process the join.

# %%
# Transform timestamp column into year, month, hours, and day of week and make the datetime the index
pd_data = dateTransform(pd_data)
pd_dev = dateTransform(pd_dev)

# parsing time, but not splitting out hours
pd_extreme=dateTransform(pd_extreme, split=False)
pd_precip=dateTransform(pd_precip, split=False)

# prepare to binarize extreme_weather
pd_extreme = binarize(pd_extreme)

# merge the external precipitation and extreme weather data into the dataset
pd_data = pd_data.join(pd_precip)
pd_dev = pd_dev.join(pd_precip)

# # pd_data = pd_data.join(pd_extreme) #NOT WORKING AND DON'T KNOW WHY
# pd_dev = pd_dev.join(pd_extreme)
# pd_data= pd_data.join(pd_extreme)

# fill in missing values for the merged columns
pd_data['precip'] = pd_data['precip'].fillna(0) # fill NAN with 0 because 0 is the median value of precip and indicates "no extreme weather" for the ex_weather column
pd_dev['precip'] = pd_dev['precip'].fillna(0) 

# pd_data['ex_weather'] = pd_data['ex_weather'].fillna(0) # fill NAN with "0" indicating "Normal Weather"
# pd_dev['ex_weather'] = pd_dev['ex_weather'].fillna(0)

# %% [markdown]
# Now we actually call the functions to clean the data and begin feature engineering. First we will convert the timestamp column into an index for each row and transform the values into more meaningful categorical values (year, month, hours, day). Then we'll make dummy columns to represent the categorical data. This, as well as making numerical columns of type float or int, as appropriate, is necessary in order to implement the LinearRegression models we experiment with later.

# %%
# save data at this "pre-dummy" point into a variable for use in the RandomForestsRegressor model
no_dum_data = pd_data
no_dum_dev = pd_dev
no_dum_labels = no_dum_data[['casual','registered','count']] # get the label columns so that we can put them at the end positions of the array
no_dum_data = no_dum_data.drop(['casual','registered','count'], 1)
no_dum_data = no_dum_data.join(no_dum_labels)

# Convert the categorical variables to a series of dummy variables (important for LinearRegression)
cat_cols = ['year', 'month', 'day', 'hours', 'season','holiday','workingday','weather']
pd_data = dummify(pd_data, cat_cols)
pd_dev =  dummify(pd_dev, cat_cols)

# Set the dtype as "float" and "int" for numerical columns (important for LinearRegression)
pd_data[['temp','atemp','humidity','windspeed']] = pd_data[['temp','atemp','humidity','windspeed']].astype(float)
pd_dev[['temp','atemp','humidity','windspeed']] = pd_dev[['temp','atemp','humidity','windspeed']].astype(float)

pd_data[['casual','registered','count']] = pd_data[['casual','registered','count']].astype(int)

# %% [markdown]
# Now that the data is cleaned and "engineered," we rearrange the columns so casual, registered, and count are at the end positions of the dataframe.

# %%
# Rearrange the dataframe so that casual, registered, and count columns are in the last column positions
labels = pd_data[['casual','registered','count']]
pd_data = pd_data.drop(['casual','registered','count'], 1)
pd_data = pd_data.join(labels)

# print pd_data.columns.values
print pd_data.shape

print pd_data.head()
# Out:
# (10886, 65)
#                      temp   atemp  humidity  windspeed  precip  year_2011  \
# datetime
# 2011-01-01 00:00:00  9.84  14.395        81          0       0          1
# 2011-01-01 01:00:00  9.02  13.635        80          0       0          1
# 2011-01-01 02:00:00  9.02  13.635        80          0       0          1
# 2011-01-01 03:00:00  9.84  14.395        75          0       0          1
# 2011-01-01 04:00:00  9.84  14.395        75          0       0          1
#
#                      year_2012  month_1  month_2  month_3   ...     holiday_1  \
# datetime                                                    ...
# 2011-01-01 00:00:00          0        1        0        0   ...             0
# 2011-01-01 01:00:00          0        1        0        0   ...             0
# 2011-01-01 02:00:00          0        1        0        0   ...             0
# 2011-01-01 03:00:00          0        1        0        0   ...             0
# ...

# %% [markdown]
# Ok, now that we have the data cleaned up, let's explore some trends in the data so we can start thinking about models.

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# Let's get a sense of how the data looks.  Here we explore the trends and distributions of some of the numerical data.

# %%
#plots
fig = plt.figure(figsize=(20,20))

ax1=fig.add_subplot(6,2,1)
ax2=fig.add_subplot(6,2,2)
ax3=fig.add_subplot(6,2,3)
ax4=fig.add_subplot(6,2,4)
ax5=fig.add_subplot(6,2,5)
ax6=fig.add_subplot(6,2,6)
ax7=fig.add_subplot(6,2,7)
ax8=fig.add_subplot(6,2,8)
ax9=fig.add_subplot(6,2,9)
ax10=fig.add_subplot(6,2,10)
ax11=fig.add_subplot(6,2,11)
ax12=fig.add_subplot(6,2,12)

ax1.plot(pd_data['count'])
ax1.set_title('time series count')
ax2.hist(pd_data['count'])
ax2.set_title('histogram of count')

ax3.plot(pd_data['temp'])
ax3.set_title('time series temp')
ax4.hist(pd_data['temp'])
ax4.set_title('histogram of temp')

ax5.plot(pd_data['humidity'])
ax5.set_title('time series hum')
ax6.hist(pd_data['humidity'])
ax6.set_title('histogram of hum')

ax7.plot(pd_data['windspeed'])
ax7.set_title('time series windspeed')
ax8.hist(pd_data['windspeed'])
ax8.set_title('histogram of windspeed')

ax9.plot(pd_data['atemp'])
ax9.set_title('time series atemp')
ax10.hist(pd_data['atemp'])
ax10.set_title('histogram of atemp')

ax11.plot(pd_data['precip'])
ax11.set_title('time series precip')
ax12.hist(pd_data['precip'])
ax12.set_title('histogram of precip')

# %% [markdown]
# We can definitely see the cyclical nature of the data, but also the growth over time (time series count).  This suggest that it may be hard to build a straight linear model, as the counts grow over time even when environmental variables may be the same.
#
# We also see the distribution of the various variables.  Some are normally distributed (so will play nice with linear models).  Others are clearly skewed, which tells us we may need to do some transformation to them to make some models work.

# %%
#lets look at the difference between casual and registered users 

#first examining usage by day of week
reg= no_dum_data.groupby('day')['registered'].agg(lambda col: col.sum()) #grouping registered by day
cas=no_dum_data.groupby('day')['casual'].agg(lambda col: col.sum()) #grouping casual by day


#building a stacked bar chart
ind=range(7)
p1=plt.bar(ind, reg, color='r')
p2=plt.bar(ind, cas,color='y', bottom=reg)
plt.legend( (p1[0], p2[0]), ('Registered', 'Casual'), loc=3)
plt.yticks(np.arange(0,400000,50000))
plt.xticks(ind, ('M', 'T', 'W', 'T', 'F', 'S', 'S'))
plt.show()

# %%
#exploring by hour of the day
reg= no_dum_data.groupby('hours')['registered'].agg(lambda col: col.sum())
cas=no_dum_data.groupby('hours')['casual'].agg(lambda col: col.sum())

#stacked bar
ind=range(24)
p1=plt.bar(ind, reg, color='r')
p2=plt.bar(ind, cas,color='y', bottom=reg)
plt.legend( (p1[0], p2[0]), ('Reg', 'Cas'), loc=0 )
plt.show()

p1=plt.bar(ind, reg, color='r')
plt.title('Registered only')
plt.show()

p3=plt.bar(ind, cas,color='y')
plt.title('Casual Only')
plt.show()

# %% [markdown]
# We can clearly see some differnce in usage.  Casual users use more on the weekend days, while registered users have higher usage on the weekdays.
#
# We can also see the difference in what time of day users used the bikes when they are casual vs. registered.  Registered users have big spikes during rush hour, but casual users mostly peak during the afternoons.
#
# This may suggest separate models for casual and registered users.

# %% [markdown]
# ## Modelling

# %% [markdown]
# Before we start modellig, we're going to need our data in training and test sets.

# %%
# First, we separate the count label column from the predictor columns, dropping registered and casual columns as predictors
count = pd_data['count']
x = pd_data.drop('count', 1)
x = x.drop(['registered', 'casual'], 1)

# Because casual bike-renters rent in different patterns than registered renters, 
# we also create data to create separate casual and registered models

# casual
casual = pd_data['casual']
x_casual = pd_data.drop('casual',1)
x_casual = x_casual.drop(['registered', 'count'],1)

# registered
registered = pd_data['registered']
x_registered = pd_data.drop('registered',1)
x_registered = x_registered.drop(['casual', 'count'],1)

# create train and test sets for registered, casual, and total count predictions
train_reg, test_reg, rtrain_labels, rtest_labels = train_test_split(x_registered, registered)
train_cas, test_cas, ctrain_labels, ctest_labels = train_test_split(x_casual, casual)
train, test, train_labels, test_labels = train_test_split(x, count)

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Woo hoo! Time for some modelling! So first we're going to try Linear Regression, which most likely is not a great classifier for this problem given the nonlinear nature of the problem. We'll create classifiers for both the casual, registered, and total count train/test sets created in the section above.

# %%
# Create three LinearRegression classifiers
lr = LinearRegression()
lr_cas = LinearRegression()
lr_reg = LinearRegression()

# Fit the models using the proper data sets
lr.fit(train, train_labels)  
lr_cas.fit(train_cas, ctrain_labels)
lr_reg.fit(train_reg, rtrain_labels)

# Get the predictions for each model
pred = lr.predict(test)
pred_cas = lr_cas.predict(test_cas)
pred_reg = lr_reg.predict(test_reg)

# Calculate the variance scores: (R squared value) where 1 is perfect prediction
lr_score = lr.score(test, test_labels)
lr_cas_score = lr_cas.score(test_cas, ctest_labels)
lr_reg_score = lr_reg.score(test_reg, rtest_labels)

print "Residual sum of squares: %.2f" % np.mean((pred - test_labels) ** 2)
print "Residual sum of squares (cas): %.2f" % np.mean((pred_cas - ctest_labels) ** 2)
print "Residual sum of squares (reg): %.2f" % np.mean((pred_reg - rtest_labels) ** 2)

print '\n\nVariance score for total count prediction: %.2f' % lr_score
print 'Variance score for casual prediction: %.2f' % lr_cas_score
print 'Variance score for registered prediction: %.2f' % lr_reg_score
# Out:
# Residual sum of squares: 10325.46
# Residual sum of squares (cas): 1033.60
# Residual sum of squares (reg): 6881.13
#
#
# Variance score for total count prediction: 0.70
# Variance score for casual prediction: 0.61
# Variance score for registered prediction: 0.69

# %% [markdown]
# So, as we said, we don't think Linear Regression is really the way to go here. Let's see what the predictions look like as compared to the actual values.

# %%
def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    
    code derived from http://nbviewer.ipython.org/github/fraser-campbell/Machine-Learning-Projects/blob/master/Bike%20Sharing/Bike%20Sharing.ipynb
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()

plt.scatter(pred, pred - test_labels, c='b', s=40, alpha = 0.25,  label='Residual for Test Data Prediction')
plt.plot([-200,600],[0,0], c='r')
plt.legend()
plt.title('Residuals vs Bike Share Count')
plt.xlabel("Predicted count values")
plt.ylabel("Residuals")

remove_border()

# %% [markdown]
# This confirms our suspicions that LinearRegression is not the way to go here. The residuals increase as the predicted count increases, meaning our model is having trouble predicting the variation in the data.
#
# Because we're looking to model count data that is governed by independent events in time, we are going to create a Poisson Regression model. For future sanity checks, a Poisson distribution is described by Wikipedia as follows:
#
# *A discrete probability distribution that expresses the probability of a given number of events occurring in a fixed interval of time and/or space if these events occur with a known average rate and independently of the time since the last event.*

# %% [markdown]
# ## Poisson Regression

# %% [markdown]
# In order to create a Poisson regression model, we just assume the logarithm of the expected count/registered/casual values can be modeled by a linear combination of unknown parameters. So let's do it!

# %%
def rmsele(actual, pred):
    """
    Given a column of predictions and a column of actuals, calculate the RMSELE
    """
    squared_errors = (np.log(pred + 1) - np.log(actual + 1)) ** 2
    mean_squared = np.sum(squared_errors) / len(squared_errors)
    return np.sqrt(mean_squared)

#define a small alpha value
alpha = 1

# instantiate log label nparrays
log_rtrain_labels = rtrain_labels.astype(float)
log_rtest_labels = rtest_labels.astype(float)
log_ctrain_labels = ctrain_labels.astype(float)
log_ctest_labels = ctest_labels.astype(float)
log_train_labels = train_labels.astype(float)
log_test_labels = test_labels.astype(float)

# replace any count values of 0 with 1 since log can't handle values of 0
log_rtrain_labels[log_rtrain_labels < 1] = alpha
log_rtest_labels[log_rtest_labels < 1] = alpha
log_ctrain_labels[log_ctrain_labels < 1] = alpha
log_ctest_labels[log_ctest_labels < 1] = alpha
log_train_labels[log_train_labels < 1] = alpha
log_test_labels[log_test_labels < 1] = alpha

# perform log transformation on the labels
log_rtrain_labels = np.log(log_rtrain_labels)
log_rtest_labels = np.log(log_rtest_labels)
log_ctrain_labels = np.log(log_ctrain_labels)
log_ctest_labels = np.log(log_ctest_labels)
log_train_labels = np.log(train_labels)
log_test_labels = np.log(test_labels)

# Create three new LinearRegression classifiers for the Poisson model
pr = LinearRegression()
pr_cas = LinearRegression()
pr_reg = LinearRegression()

# Fit the models using the proper data sets
pr.fit(train, log_train_labels)  
pr_cas.fit(train_cas, log_ctrain_labels)
pr_reg.fit(train_reg, log_rtrain_labels)

# Get the predictions for each model
poisson_pred = pr.predict(test)
poisson_pred_cas = pr_cas.predict(test_cas)
poisson_pred_reg = pr_reg.predict(test_reg)
# combined_pred = np.add(np.exp(poisson_pred_cas), np.exp(poisson_pred_reg))

# Calculate the variance scores: (R squared value) where 1 is perfect prediction
pr_score = pr.score(test, log_test_labels)
pr_cas_score = pr_cas.score(test_cas, log_ctest_labels)
pr_reg_score = pr_reg.score(test_reg, log_rtest_labels)

print "Root Mean Squared Logarithmic Error for Count: ", rmsele(np.exp(poisson_pred), np.exp(log_test_labels))
print "Test accuracy for Count: %0.2f%%" % (100*pr_score) + "\n"

print "Root Mean Squared Logarithmic Error for Casual: ", rmsele(np.exp(poisson_pred_cas), np.exp(log_ctest_labels))
print "Test accuracy for Casual: %0.2f%%" % (100*pr_cas_score) + "\n"

print "Root Mean Squared Logarithmic Error for Registered: ", rmsele(np.exp(poisson_pred_reg), np.exp(log_rtest_labels))
print "Test accuracy for Registered: %0.2f%%" % (100*pr_reg_score) + "\n"
# Out:
# Root Mean Squared Logarithmic Error for Count:  0.58009762038
# Test accuracy for Count: 82.90%
#
# Root Mean Squared Logarithmic Error for Casual:  0.558001979597
# Test accuracy for Casual: 82.10%
#
# Root Mean Squared Logarithmic Error for Registered:  0.582602016633
# Test accuracy for Registered: 82.51%

# %% [markdown]
# Let's check out the Predicted vs Fitted plot again, but this time for the Poisson model.

# %%
plt.scatter(np.exp(poisson_pred), np.exp(log_test_labels))
plt.title("Poisson Regression Model Prediction")
plt.ylabel("Actual Rental Counts")
plt.xlabel("Predicted Rental Counts")
plt.xlim(0, 1000)
plt.ylim(0, 1000)
remove_border()

# %% [markdown]
# Yay! That was a good improvement. But there are still issues with outliers (large counts are less likely to be predicted well). Basically, our model doesn't detect anomalies well. Let's try some different models to see if we can get the prediction error to decrease.

# %% [markdown]
# ## Random Forests

# %%
# create the predictors data and the labels data
rf_labels = no_dum_data['count'].astype(int)
rf_data = no_dum_data.drop(['count', 'casual','registered'], 1)

# split the data into training and test sets
xtrain, xtest, ytrain, ytest = train_test_split(rf_data, rf_labels)

# Model Running with optimum parameters on entire training set
rf_clf = RandomForestRegressor(n_jobs=1, n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_features = 'auto', oob_score=True)
rf_clf.fit(xtrain, ytrain)
preds = rf_clf.predict(xtest).astype(int)

# plot of predicted vs actual counts
plt.scatter(preds, ytest)
plt.title("Random Forest Model Prediction")
plt.ylabel("Actual Rental Counts")
plt.xlabel("Predicted Rental Counts")
plt.xlim(0, 1000)
plt.ylim(0, 1000)
remove_border()

#Root Mean Squared Logarithmic Error (RMSLE) and accuracy score
print "\nRoot Mean Squared Logarithmic Error Test: ", rmsele(preds, ytest)
print "Test accuracy: %0.2f%%" % (100*rf_clf.score(xtest, ytest)) + "\n"
# Out:
# Root Mean Squared Logarithmic Error Test:  0.324255015368
# Test accuracy: 95.57%

# %% [markdown]
# This model does a really nice job of predicting counts. The errors are pretty evenly distributed across all count values, unlike in the regression models.
#
# But since we're still having some issues, let's try an Extra Trees Regressor. That way we are using more randomized decision trees and can perhaps predict some anomolies better.

# %%
et_clf = ExtraTreesRegressor(n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features='auto', n_jobs=1)
et_clf.fit(xtrain, ytrain)
et_preds = et_clf.predict(xtest).astype(int)

# plot of predicted vs actual counts
plt.scatter(preds, ytest)
plt.title("Extra Trees Regressor Prediction")
plt.ylabel("Actual Rental Counts")
plt.xlabel("Predicted Rental Counts")
plt.xlim(0, 1000)
plt.ylim(0, 1000)
remove_border()

#Root Mean Squared Logarithmic Error (RMSLE) and accuracy score
print "\nRoot Mean Squared Logarithmic Error Test: ", rmsele(et_preds, ytest)
print "Test accuracy: %0.2f%%" % (100*et_clf.score(xtest, ytest)) + "\n"

# %% [markdown]
# That produced our best results, so we ran the model with the full dataset below and submitted to Kaggle. The randomized decision trees detected anomalies well while also learning the fluctuating patterns in the data.

# %% [markdown]
# ### Final Kaggle Submission

# %% [markdown]
# At this moment, Extra Trees Regressor works best, so this will be used in our Kaggle submission.

# %%
# Kaggle submission

final_clf = ExtraTreesRegressor(n_estimators=1000, min_samples_split=2, min_samples_leaf=2, max_features='auto', n_jobs=1)
final_clf.fit(rf_data, rf_labels)
dev_counts = final_clf.predict(no_dum_dev).astype(int)

# zip these predictions with the datetime for that prediction
precsv = zip(timestamps, dev_counts)

# output to csv
f = open("precip_submission.csv", 'w+')
try:
    writer = csv.writer(f)
    writer.writerow( ('datetime', 'count') )
    for row in precsv:
        writer.writerow( row )
finally:
    f.close()

# %% [markdown]
# # Other Models

# %% [markdown]
# ### Neural Network

# %% [markdown]
# We attempted a Neural Network as a learning process, even though it's not the best method to approach this question. Neural Network is usually better at problems that humans are good at by computers are bad. They're usually good at pattern recognition and problems with a lot of noise, which this problem is neither of those. Artifical Neural Network is suppose to be good for problems with a time element. However, overtraining can be an issue with ANN.

# %%
# We tried using pybrain
from pybrain import *
from pybrain.tools.shortcuts import buildNetwork
from pybrain.datasets import SupervisedDataSet
from pybrain.supervised.trainers import BackpropTrainer
from pybrain.structure import SoftmaxLayer
from pybrain.structure import GaussianLayer
from pybrain.structure import TanhLayer

# %%
ds = SupervisedDataSet(63,1) #Tranforming the data into the right format
for i in range(0,len(train_labels)):
    ds.addSample(train[i,:], train_labels[i])

net = buildNetwork(63,64,1, hiddenclass=TanhLayer) #We tried different inner layer 
trainer = BackpropTrainer(net,ds)
trainer.train() #However, the output error is quite large
# Out:
# 24336.822984801831

# %% [markdown]
# ### K-Nearest-Neighbor

# %% [markdown]
# We tried KNN Regressor as a method to start and see if it can beat the normal regression. It improved the residual sum of squares but still does not seem to be the best method. KNN is easy to implement and is robust to noisy data by harder to get an accurate response.

# %%
# fit estimator
est = KNeighborsRegressor(n_neighbors=10, metric='manhattan', p=1)
est.fit(train, train_labels)

# predict class labels
pred = est.predict(test).astype(int)

plt.scatter(pred, test_labels)
plt.title("KNN Predictions")
plt.ylabel("Actual Rental Counts")
plt.xlabel("Predicted Rental Counts")
plt.xlim(0, 1000)
plt.ylim(0, 1000)

# score on test data (accuracy)
print "Accuracy: %.2f" % est.score(test, test_labels)
print "Residual sum of squares: %.2f" % np.mean((est.predict(test) - test_labels) ** 2)
# Out:
# Accuracy: 0.40
# Residual sum of squares: 18913.43

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# The Decision Tree method drasticaly improved both of accuracy and lowered error. While Decision Tree can generate understandable rule and is able to provide clear indication on which fiels are most important for predictions, it's less optimal for predicting continuous values. It sometimes can also create over-complex trees that may not generalize the data well (i.e. overfitting). SKlearn's documentation has very good summary regarding its advantages and disadvantages (http://scikit-learn.org/stable/modules/tree.html#tree)

# %%
# fit estimator
clf = tree.DecisionTreeRegressor()
clf = clf.fit(train, train_labels)

# predict class labels
pred = clf.predict(test).astype(int)

plt.scatter(pred, test_labels)
plt.title("Decision Tree Predictions")
plt.ylabel("Actual Rental Counts")
plt.xlabel("Predicted Rental Counts")
plt.xlim(0, 1000)
plt.ylim(0, 1000)

print "Accuracy: %.2f" % clf.score(test, test_labels)
print "Residual sum of squares: %.2f" % np.mean((clf.predict(test) - test_labels) ** 2)
# Out:
# Accuracy: 0.85
# Residual sum of squares: 4684.25

# %% [markdown]
# ### Gradient Tree Boosting

# %% [markdown]
# Gradient Tree Boosting gave us really good results (sometimes better accuracy and less error than RandomForest or ExtraTrees). However, its prediction sometimes contains negative values, which we have not found a proper way to handle. It's also very computationally intensive. Boosting is known to reduce both the variance and bias of simple classifier (such as one node trees). It's good at handling data of mixed type and is robust to outliers. However, it's difficult to scale/parallel.

# %%
# fit estimator
est = GradientBoostingRegressor(n_estimators=2000, max_depth=3)
est.fit(xtrain, ytrain)

# predict class labels
pred = est.predict(xtest).astype(int)

plt.scatter(pred, ytest)
plt.title("Gradient Boosting Predictions")
plt.ylabel("Actual Rental Counts")
plt.xlabel("Predicted Rental Counts")
plt.xlim(0, 1000)
plt.ylim(0, 1000)

# score on test data (accuracy)
print "Accuracy: %.2f" % est.score(xtest, ytest)
print "Residual sum of squares: %.2f" % np.mean((est.predict(xtest) - ytest) ** 2)
# Out:
# Accuracy: 0.94
# Residual sum of squares: 1815.85

# %% [markdown]
# ### Extra Trees

# %% [markdown]
# Extra Trees Regressor also returns very good results. These are all ensemble methods, which use multiple learning algorithms to obtain better predictive performance (wikipedia).

# %%
# fit estimator
clf2 = ExtraTreesRegressor(n_jobs=1, n_estimators=1000, min_samples_leaf=2, min_samples_split=2, max_features = 'auto')
clf2 = clf2.fit(train, train_labels)

# predict class labels
pred = clf2.predict(test).astype(int)

plt.scatter(pred, test_labels)
plt.title("Extra Trees Predictions")
plt.ylabel("Actual Rental Counts")
plt.xlabel("Predicted Rental Counts")
plt.xlim(0, 1000)
plt.ylim(0, 1000)

# score on test data
print "Accuracy: %.2f" % clf2.score(test, test_labels)
print "Residual sum of squares: %.2f" % np.mean((clf2.predict(test) - test_labels) ** 2)
# Out:
# Accuracy: 0.93
# Residual sum of squares: 2102.18

# %% [markdown]
# ## Future Work

# %% [markdown]
# We didn't get the chance to really play around with different feature combinations. Most of our models just used all features, even though we know that this isn't the best option.
#
# We also saw the different patterns between registered and casual users and created data to run separate models for each user base, but have not actually proceeded to use different models for registered vs casual prediction.
#
# Ensemble methods seem to work well with these type of data. We were unable to try Bagging Regressor or spend more time trying to figure out how to handle the negative outputs from Gradient Boosting. We also would still like to try to create a neural net for this problem, but chose to pursue other options given the nature of the problem. The neural net approach was more for our own learning objectives than for the suitability of the problem.
